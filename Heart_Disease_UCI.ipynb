# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
heart=pd.read_csv('heart_disease_UCI.csv')

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
plt.figure(figsize=(18,9))
sns.heatmap(heart.corr(),annot=True)

# %%
sns.distplot(heart['age'])

# %%
ax1=plt.figure(figsize=(12,7))
plt.hist(heart['age'])
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='age',hue='target',data=heart)

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='sex',y='age',hue='target',data=heart)

# %%
heart['sexes']=heart['sex'].map({0:'Female',1:'Male'})
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target   sexes
# 0   0     1       1    Male
# 1   0     2       1    Male
# 2   0     2       1  Female
# 3   0     2       1    Male
# 4   0     2       1  Female

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='sexes',y='age',hue='target',data=heart)

# %%
sns.countplot(x='exang',hue='sexes',data=heart)

# %%
sns.countplot(x='exang',hue='target',data=heart)

# %%
sns.countplot(x='ca',hue='target',data=heart)

# %%
plt.figure(figsize=(12,7))
plt.hist(heart['trestbps'])
plt.xlabel('Resting Blood Pressure')
# Out:
# Text(0.5, 0, 'Resting Blood Pressure')

# %%
fig=plt.figure(figsize=(12,7))
plt.hist(heart['chol'])
plt.xlabel('serum cholesterol in mg/dl ')
# Out:
# Text(0.5, 0, 'serum cholesterol in mg/dl ')

# %%
sns.countplot(x='fbs',hue='target',data=heart)
plt.xlabel('Fasting Blood Sugar:If fasting blood sugar > 120mg/dl then : 1 (true) else : 0 (false)')
# Out:
# Text(0.5, 0, 'Fasting Blood Sugar:If fasting blood sugar > 120mg/dl then : 1 (true) else : 0 (false)')

# %%
sns.countplot(x='thal',data=heart)
plt.xlabel('Thalassemia (1 = normal, 2 = fixed defect, 3 = reversible defect)')
# Out:
# Text(0.5, 0, 'Thalassemia (1 = normal, 2 = fixed defect, 3 = reversible defect)')

# %%
sns.countplot(x='thal',data=heart,hue='target')
plt.xlabel('Thalassemia (1 = normal, 2 = fixed defect, 3 = reversible defect)')
# Out:
# Text(0.5, 0, 'Thalassemia (1 = normal, 2 = fixed defect, 3 = reversible defect)')

# %%
sns.lmplot(x='chol',y='trestbps',data=heart)

# %%
sns.distplot(heart['thalach'])
plt.xlabel('Max heart rate achieved')
# Out:
# Text(0.5, 0, 'Max heart rate achieved')

# %%
plt.hist(heart['thalach'])
plt.xlabel('Max heart rate achieved')
# Out:
# Text(0.5, 0, 'Max heart rate achieved')
